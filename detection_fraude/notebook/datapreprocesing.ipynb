# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#========CHARGER LE DATASET==================
df = pd.read_csv("../data/processed/fraud_dataset.csv")
df.head()
print(df.column().count())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 4
#       1 #========CHARGER LE DATASET==================
#       2 df = pd.read_csv("../data/processed/fraud_dataset.csv")
#       3 df.head()
# ----> 4 print(df.column.count())
#
# File c:\Users\Najoro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
#================NETOYER LES DATASET=================

# %%
#==================CHARGER LE DATASET PROPRE=============
